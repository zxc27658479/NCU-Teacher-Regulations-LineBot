# %%
pip install line-bot-sdk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -iohttp (e:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -iohttp (e:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -iohttp (e:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -iohttp (e:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -iohttp (e:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -iohttp (e:\anaconda\lib\site-packages)

# %%
from flask import Flask, request, abort

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    ReplyMessageRequest,
    TextMessage,
    QuickReply,
    QuickReplyItem,
    MessageAction,
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent
)

app = Flask(__name__)

configuration = Configuration(access_token='3cr/+n7t7z7I0qs9rDDSu8i3T1y1LaQ+F6R5pm4l27jE1yUxkLD7z6tY4AtihSYaKa+X2CMPXrhvdcYH5zFvsEzhWXH47A0FHoJjsfI2hbZM2yu2QCuvwEMz+NxnSI9xWYFRnIC2LTcZ8Hff45jEfgdB04t89/1O/w1cDnyilFU=')
handler = WebhookHandler('f4949399f3f5584661547ff355573385')


@app.route("/callback", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    mtext = event.message.text
    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)
        if mtext == "@自我介紹":
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(reply_token=event.reply_token,messages=[TextMessage(text="教師您好，我是教師規章機器人，能為您提供便捷的規章資訊。")])
            ) 
        elif mtext == "@規章選單":
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(reply_token=event.reply_token,messages=[TextMessage(
                                text="請選擇您欲了解的規章條例",
                                quick_reply = QuickReply(
                                items=[
                                    QuickReplyItem(action=MessageAction(label="新聘教師教學經費補助辦法", text="新聘教師教學經費補助辦法")),
                                    QuickReplyItem(action=MessageAction(label="教師請假補課調課代課規定",text="教師請假補課調課代課規定")),
                                    QuickReplyItem(action=MessageAction(label="優良教研人員教勵辦法", text="優良教研人員教勵辦法")),
                                    QuickReplyItem(action=MessageAction(label="新聘傑出教研人員獎勵辦法", text="新聘傑出教研人員獎勵辦法")),
                                    QuickReplyItem(action=MessageAction(label="新進或年輕傑出教研人員學術研究補助辦法", text="新進或年輕傑出教研人員學術研究補助辦法")),
                                    QuickReplyItem(action=MessageAction(label="羅家倫校長年輕傑出研究獎設置辦法", text="羅家倫校長年輕傑出研究獎設置辦法")),
                                    QuickReplyItem(action=MessageAction(label="人社領域教學優良教師研究補助辦法", text="人社領域教學優良教師研究補助辦法")),
                                    QuickReplyItem(action=MessageAction(label="教研人員教學、研究、輔導及服務獎勵辦法", text="教研人員教學、研究、輔導及服務獎勵辦法")),
                                ]))])
            )
        elif mtext == "@快速鏈接":
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(reply_token=event.reply_token,messages=[TextMessage(text="若您覺得我說得不夠詳細，我這邊為您整理了所有規章的鏈接:\
                                                                                        \n\n新聘教師教學經費補助辦法:https://reurl.cc/rraVkO \
                                                                                        \n\n教師請假補課調課代課規定: https://reurl.cc/aL5Dz3 \
                                                                                        \n\n優良教研人員教勵辦法: https://reurl.cc/G4dYlG \
                                                                                        \n\n新聘傑出教研人員獎勵辦法: https://reurl.cc/g48orb \
                                                                                        \n\n新進或年輕傑出教研人員學術研究補助辦法: https://reurl.cc/prmRVQ \
                                                                                        \n\n羅家倫校長年輕傑出研究獎設置辦法: https://reurl.cc/E42v0a \
                                                                                        \n\n人社領域教學優良教師研究補助辦法: https://reurl.cc/G4dY03 \
                                                                                        \n\n教研人員教學、研究、輔導及服務獎勵辦法: https://reurl.cc/54oN6y")])
            )
        elif mtext == "新聘教師教學經費補助辦法":
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(reply_token=event.reply_token,messages=[TextMessage(text="申請人限為本校服務未滿(含)三年之新進教師，最高額度十萬元，申請者應檢具計畫書與填具申請表於每年教務處公告期間提出申請。每人補助一次為限。")])
            )
        elif mtext == "教師請假補課調課代課規定":
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(reply_token=event.reply_token,messages=[TextMessage(text="教師請假未能事先安排補課、調課者，請於銷假後一週內，由任課老師與學生商定 補課時間，並知會開課單位。")])
            )
        elif mtext == "優良教研人員教勵辦法":
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(reply_token=event.reply_token,messages=[TextMessage(text="本獎勵每人每年以2 千元為原則。 適用對象：本校專任（案）教研人員、助教、教官，在教學、研究、輔 導及服務有貢獻者。 含帶職帶薪休假研究、講學、進修及育嬰留職停薪 之教研人員，不含博士後研究員、除育嬰外留職停薪之教研人員。")])
            )
        elif mtext == "新聘傑出教研人員獎勵辦法":
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(reply_token=event.reply_token,messages=[TextMessage(text="獎勵對象為本校國內第一次聘任之新進專任教研人員。於到職日起三年內得申請本獎勵。獎金以每月一萬元至二萬元為原則，獎勵期間以一年為限，獎金原則逐月領取。")])
            )
        elif mtext == "新進或年輕傑出教研人員學術研究補助辦法":
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(reply_token=event.reply_token,messages=[TextMessage(text="1.新進教研人員研究相關補助至多20萬元。\n2.年輕傑出教研人員相關補助至多50-100萬。(暫停補助)\n3.補助經費執行期限次年度1月起至12月止。")])
            )
        elif mtext == "羅家倫校長年輕傑出研究獎設置辦法":
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(reply_token=event.reply_token,messages=[TextMessage(text="獎勵方式: \n1.獲獎人數每年以2至4人為原則。 \n2.每人獎金60萬元，按月發給，為期一年。 \n3.獲獎人以獲頒一次獎項為限。")])
            )
        elif mtext == "人社領域教學優良教師研究補助辦法":
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(reply_token=event.reply_token,messages=[TextMessage(text="對象為文學院、管理學院、客家學院及人社相關領域之助理教授級以上專任（專案）教師，每案補助設備費及其他費用以十五萬元為原則，本辦法補助以三次為限，得於五年內提出申請。")])
            )
        elif mtext == "教研人員教學、研究、輔導及服務獎勵辦法":
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(reply_token=event.reply_token,messages=[TextMessage(text="獎金支領人數核給比例：\n1.講座教授：以不超過全校專任(案)教研人員之6%為原則。\n2.特聘教授：以不超過全校專任(案)教研人員之11%為原則。\n3.研究傑出獎：以不超過全校專任(案)教研人員之19%為原則。\n4.新聘傑出教研人員獎勵：以不超過全校專任(案)教研人員之4% 為原則。")])
            )
        line_bot_api.reply_message_with_http_info(
            ReplyMessageRequest(
                reply_token=event.reply_token,
                messages=[TextMessage(text=event.message.text)]
            )
        )

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [28/Dec/2023 17:15:06] "POST /callback HTTP/1.1" 200 -
# [2023-12-28 17:16:39,796] ERROR in app: Exception on /callback [POST]
# Traceback (most recent call last):
#   File "E:\Anaconda\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "E:\Anaconda\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "E:\Anaconda\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "E:\Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
# ...
